# %%
import pandas as pd

# %%
nfl_file_path = './wr-top24-data.csv'
nfl_data = pd.read_csv(nfl_file_path) 
nfl_data.describe()
# Out:
#        # of Top 5 Szns  # of Top 12 Szns  # of Top 24 Szns       Draft  \
# count       390.000000        390.000000        390.000000  390.000000
# mean          0.807692          1.702564          3.112821  102.284615
# std           1.383503          1.783600          2.030004  106.035758
# min           0.000000          0.000000          1.000000    4.000000
# 25%           0.000000          0.000000          1.000000   26.250000
# 50%           0.000000          1.000000          3.000000   63.000000
# 75%           1.000000          3.000000          5.000000  101.000000
# max           6.000000          7.000000          8.000000  329.000000
#
#               Age   Draft Year     Cr.Year     SZN Year      POS RK  \
# count  390.000000   390.000000  390.000000   390.000000  390.000000
# mean    25.376923  2013.133333    4.138462  2016.271795   44.853846
# std      2.622619     2.520388    2.471703     2.697800   42.238662
# ...
